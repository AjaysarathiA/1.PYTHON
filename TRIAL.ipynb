# %%
age=int(input("ENTER YOUR AGE:"))
if(age<18):
        print("Child")
elif(age<35):
        print("adult")
elif(age<60):
        print("citizen")
else:
        print("senior citizen")
# Out:
# ENTER YOUR AGE: 17
# Child
