# %%
Num1=12
Num2=18
Add=Num1+Num2
print("Add")
print(Add)
# Out:
# Add
# 30

# %%
num1=int(input("Enter the number1:"))
num2=int(input("Enter the number2:"))
print("Addition:",num1+num2)
# Out:
# Enter the number1: 58
# Enter the number2: 62
# Addition: 120
